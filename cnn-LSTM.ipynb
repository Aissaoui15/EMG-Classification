# %%
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.io
import scipy
from scipy import signal

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

import math

# %%
""" Define schema of datasets
"""

DATABASE = {
    'Database 1': ['female_1',
                  'female_2',
                  'female_3',
                  'male_1',
                  'male_2'],
    'Database 2': ['male_day_1',
                  'male_day_2',
                  'male_day_3']
}

COLUMNS = ['cyl_ch1', 
            'cyl_ch2', 
            'hook_ch1', 
            'hook_ch2', 
            'tip_ch1', 
            'tip_ch2', 
            'palm_ch1', 
            'palm_ch2', 
            'spher_ch1', 
            'spher_ch2', 
            'lat_ch1', 
            'lat_ch2']

LABELS = [
    'Spherical',
    'Tip',
    'Palmar',
    'Lateral',
    'Cylindrical',
    'Hook'
]

COL_MAPPINGS = {
            'cyl_ch1': 'Cylindrical', 
            'cyl_ch2': 'Cylindrical', 
            'hook_ch1': 'Hook', 
            'hook_ch2': 'Hook', 
            'tip_ch1': 'Tip', 
            'tip_ch2': 'Tip', 
            'palm_ch1': 'Palmar', 
            'palm_ch2': 'Palmar', 
            'spher_ch1': 'Spherical', 
            'spher_ch2': 'Spherical', 
            'lat_ch1': 'Lateral', 
            'lat_ch2': 'Lateral'
}

# %%
""" Preprocess and standardize dataset into a single dataframe table
"""

DB_NAME = 'Database 1'
dfs = []
for fname in DATABASE[DB_NAME]: 
    tmp_data = scipy.io.loadmat(f'./data/{DB_NAME}/{fname}')
    tmp_data = {k:v for k,v in tmp_data.items() if k in COLUMNS}
    for c in COLUMNS:
        tmp_dfx = pd.DataFrame(tmp_data[c])
        tmp_dfx['identifier'] = fname
        tmp_dfx['label'] = COL_MAPPINGS[c]
        dfs.append(pd.DataFrame(tmp_dfx))

dataset = pd.concat(dfs)
print("Dimensions", dataset.shape)
dataset.head()
# Out:
# Dimensions (1800, 3002)
#           0         1         2         3         4         5         6  \
# 0  0.072198  0.276211  0.429221  0.327214  0.123201  0.097700  0.072198
# 1  0.250710  0.301713  0.199706  0.378218  0.021195 -0.080812 -0.106313
# 2  0.123201  0.148703  0.148703  0.123201 -0.004307 -0.157317 -0.029808
# 3  0.531228 -0.106313 -0.284825 -0.335828 -0.182818  0.123201  0.301713
# 4 -0.310326 -0.182818  0.276211  0.480224  0.352716  0.123201  0.123201
#
#           7         8         9  ...      2992      2993      2994      2995  \
# 0  0.021195 -0.004307  0.174205  ...  0.276211 -0.259323  0.072198  1.882814
# 1  0.021195  0.276211  0.072198  ... -1.304890  0.786244  0.786244  0.939254
# 2  0.174205  0.199706  0.250710  ... -0.233821  0.403719  0.046696 -0.080812
# 3  0.352716  0.327214 -0.029808  ...  0.709739  0.276211 -0.080812  0.123201
# 4  0.097700 -0.029808 -0.080812  ... -0.208320  0.429221  0.378218  0.633234
#
#        2996      2997      2998      2999  identifier        label
# 0  0.480224 -2.528968  0.097700  0.837247    female_1  Cylindrical
# 1  1.270775 -0.616346  0.454723  0.021195    female_1  Cylindrical
# 2  0.378218 -0.361330  0.505726  0.607732    female_1  Cylindrical
# 3  0.735241  1.270775 -0.769356 -1.687415    female_1  Cylindrical
# 4  0.811746  0.403719 -0.182818 -0.412333    female_1  Cylindrical
#
# [5 rows x 3002 columns]

# %%
#combine coupled readouts
new_dfs = []
for lab in LABELS:
    new_temp = dataset[dataset['label'] == lab].values
    new_temp_comb = pd.DataFrame(np.concatenate((new_temp[:150,:3000],new_temp[150:,:3002]),axis=1))
    new_dfs.append(new_temp_comb)


new_dataset = pd.concat(new_dfs)
new_dataset.rename(columns={6001:'label', 6000:'identifier'}, inplace=True)
print("Dimension", new_dataset.shape)
new_dataset.head()
# Out:
# Dimension (900, 6002)
#           0         1         2         3         4         5         6  \
# 0  0.505726  0.531228  0.505726  0.021195  0.046696 -0.080812  0.021195
# 1  0.454723  0.174205 -0.182818 -0.386831  0.709739  0.633234 -0.029808
# 2  1.245273  0.123201 -2.273952 -2.936995 -0.335828   1.50029  1.398283
# 3 -0.080812 -0.182818    0.0977  0.123201  0.276211  0.352716   0.25071
# 4  0.480224  0.021195  0.429221  0.021195 -0.004307 -0.106313  0.199706
#
#           7         8         9  ...      5992      5993      5994      5995  \
# 0  0.021195  0.123201  0.199706  ...  0.227693  0.049139  -0.30797 -0.103908
# 1  -0.20832    0.0977  0.582231  ... -0.333478  0.100154   0.71234  0.610309
# 2  2.163332  0.403719 -0.131815  ...  0.253201 -0.486524 -0.231447  -0.30797
# 3  0.199706    0.0977 -0.080812  ...  0.227693 -0.818125 -0.052892  0.431755
# 4  0.199706  0.301713  0.276211  ... -0.103908 -1.124218  0.278708   0.94191
#
#        5996      5997      5998      5999 identifier      label
# 0  0.100154   0.15117 -0.614063 -0.358985   female_3  Spherical
# 1  0.559294 -0.410001  0.253201 -0.052892   female_3  Spherical
# 2  0.100154  0.865386  0.635817   0.15117   female_3  Spherical
# 3  0.457263  0.304216  0.125662  0.304216   female_3  Spherical
# 4  0.686832  0.023631 -1.124218 -0.333478   female_3  Spherical
#
# [5 rows x 6002 columns]

# %%
from cgitb import Hook


def abs_val_filter(data):
    """ Apply an absolute value filter to a DataFrame
    """
    return abs(data.copy())

def butterworth_low_pass_filter(data,     
                                frequency=500,         # sampling frequency
                                lp_filter=5,           # cutoff frequency
                                order=4):
    """
    Create a low pass filter to eliminate noise and smooth EMG data 
    
    The data were collected at a sampling rate of 500 Hz, 
    using as a programming kernel the National Instruments (NI) Labview. 
    The signals were band-pass filtered using a Butterworth Band Pass filter 
    with low and high cutoff at 15Hz and 500Hz respectively and a notch filter at 50Hz 
    to eliminate line interference artifacts.
    """
    lp_filter = lp_filter/(frequency/2)

    # Create a lowpass butterworth signal 
    B, A = scipy.signal.butter(order, 
                               lp_filter, 
                               btype='lowpass')


    # Apply the lowpass signal filter to EMG data
    smooth_emg = scipy.signal.filtfilt(B, 
                                       A, 
                                       data)
    return smooth_emg


def holt_smoothing(data,
                  s_level = 0.5,
                  s_slope = 0.1):
    smoothed = Hook(data[0]).fit(smoothing_level=s_level, smoothing_slope=s_slope).fittedvalues[:]
    print(data[0])
    print(smoothed)
    return smoothed

# %%
df_features = new_dataset.iloc[:,:6000].copy()
df_labels = new_dataset.iloc[:, 6001]
df_features = abs_val_filter(df_features)

# %%
smoothed_emg_df = butterworth_low_pass_filter(df_features.to_numpy(),
                                             frequency=5000,
                                             lp_filter=25)

# %%
from sklearn.preprocessing import OneHotEncoder
Y = df_labels
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data in to Train and Test
x_train, x_test, y_train, y_test = train_test_split(smoothed_emg_df, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((675, 6000), (675, 6), (225, 6000), (225, 6))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((675, 6000), (675, 6), (225, 6000), (225, 6))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((675, 6000, 1), (675, 6), (225, 6000, 1), (225, 6))

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import Dropout, LSTM, ConvLSTM1D, Bidirectional
import os
from tqdm import tqdm
import cv2
from glob import glob
import seaborn as sns
sns.set()

import sklearn
import skimage
from skimage.transform import resize

from skimage.color import rgb2gray
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
from keras.layers.normalization import batch_normalization

# %%
model=models.Sequential()
model.add(layers.Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(layers.Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(layers.Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(layers.Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

model.add(layers.Flatten())
model.add(layers.Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(layers.Dense(units=6, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6000, 256)         1536
#
#  max_pooling1d (MaxPooling1D  (None, 3000, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 3000, 256)         327936
#
#  max_pooling1d_1 (MaxPooling  (None, 1500, 256)        0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 1500, 128)         163968
#
#  max_pooling1d_2 (MaxPooling  (None, 750, 128)         0
#  1D)
#
#  dropout (Dropout)           (None, 750, 128)          0
#
#  conv1d_3 (Conv1D)           (None, 750, 64)           41024
#
#  max_pooling1d_3 (MaxPooling  (None, 375, 64)          0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 375, 200)         132000
#  l)
#
#  dropout_1 (Dropout)         (None, 375, 200)          0
#
#  bidirectional_1 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  flatten (Flatten)           (None, 200)               0
#
#  dense (Dense)               (None, 32)                6432
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 913,894
# Trainable params: 913,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau

# %%
learning_Reduce = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[learning_Reduce])
# Out:
# Epoch 1/50
# 11/11 [==============================] - 300s 20s/step - loss: 1.7583 - accuracy: 0.2044 - val_loss: 1.6395 - val_accuracy: 0.3378 - lr: 0.0010
# Epoch 2/50
# 11/11 [==============================] - 170s 16s/step - loss: 1.5876 - accuracy: 0.3244 - val_loss: 1.4304 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 3/50
# 11/11 [==============================] - 174s 16s/step - loss: 1.5117 - accuracy: 0.3644 - val_loss: 1.3876 - val_accuracy: 0.3644 - lr: 0.0010
# Epoch 4/50
# 11/11 [==============================] - 173s 16s/step - loss: 1.4703 - accuracy: 0.3763 - val_loss: 1.3496 - val_accuracy: 0.3733 - lr: 0.0010
# Epoch 5/50
# 11/11 [==============================] - 173s 16s/step - loss: 1.4450 - accuracy: 0.3570 - val_loss: 1.3179 - val_accuracy: 0.4178 - lr: 0.0010
# Epoch 6/50
# 11/11 [==============================] - 175s 16s/step - loss: 1.3774 - accuracy: 0.4178 - val_loss: 1.3066 - val_accuracy: 0.3911 - lr: 0.0010
# Epoch 7/50
# 11/11 [==============================] - 200s 18s/step - loss: 1.3639 - accuracy: 0.3941 - val_loss: 1.2762 - val_accuracy: 0.4133 - lr: 0.0010
# Epoch 8/50
# 11/11 [==============================] - 177s 16s/step - loss: 1.3330 - accuracy: 0.4119 - val_loss: 1.2599 - val_accuracy: 0.4044 - lr: 0.0010
# Epoch 9/50
# 11/11 [==============================] - 174s 16s/step - loss: 1.3242 - accuracy: 0.4015 - val_loss: 1.2167 - val_accuracy: 0.4400 - lr: 0.0010
# Epoch 10/50
# 11/11 [==============================] - 175s 16s/step - loss: 1.2941 - accuracy: 0.4415 - val_loss: 1.3408 - val_accuracy: 0.4356 - lr: 0.0010
# Epoch 11/50
# 11/11 [==============================] - 173s 16s/step - loss: 1.3264 - accuracy: 0.4296 - val_loss: 1.3184 - val_accuracy: 0.4400 - lr: 0.0010
# Epoch 12/50
# 11/11 [==============================] - 174s 16s/step - loss: 1.2747 - accuracy: 0.4237 - val_loss: 1.2175 - val_accuracy: 0.4578 - lr: 0.0010
# Epoch 13/50
# 11/11 [==============================] - 175s 16s/step - loss: 1.2723 - accuracy: 0.4281 - val_loss: 1.1984 - val_accuracy: 0.4756 - lr: 0.0010
# Epoch 14/50
# 11/11 [==============================] - 177s 16s/step - loss: 1.2152 - accuracy: 0.4874 - val_loss: 1.1594 - val_accuracy: 0.4711 - lr: 0.0010
# Epoch 15/50
# 11/11 [==============================] - 174s 16s/step - loss: 1.2458 - accuracy: 0.4444 - val_loss: 1.2238 - val_accuracy: 0.4978 - lr: 0.0010
# Epoch 16/50
# 11/11 [==============================] - 175s 16s/step - loss: 1.2331 - accuracy: 0.4489 - val_loss: 1.1526 - val_accuracy: 0.4800 - lr: 0.0010
# Epoch 17/50
# 11/11 [==============================] - 205s 19s/step - loss: 1.1503 - accuracy: 0.5067 - val_loss: 1.1217 - val_accuracy: 0.5200 - lr: 4.0000e-04
# Epoch 18/50
# 11/11 [==============================] - 312s 30s/step - loss: 1.1533 - accuracy: 0.5037 - val_loss: 1.1365 - val_accuracy: 0.4844 - lr: 4.0000e-041.1804 - accuracy: 0.50 - ETA: 4:50 - loss: 1.1681 - a
# Epoch 19/50
# 11/11 [==============================] - 190s 17s/step - loss: 1.1242 - accuracy: 0.4904 - val_loss: 1.0995 - val_accuracy: 0.5244 - lr: 4.0000e-04
# Epoch 20/50
# 11/11 [==============================] - 173s 16s/step - loss: 1.1192 - accuracy: 0.5007 - val_loss: 1.0664 - val_accuracy: 0.5556 - lr: 4.0000e-04
# Epoch 21/50
# 11/11 [==============================] - 203s 19s/step - loss: 1.1123 - accuracy: 0.5126 - val_loss: 1.0838 - val_accuracy: 0.5511 - lr: 4.0000e-04
# Epoch 22/50
# 11/11 [==============================] - 171s 16s/step - loss: 1.1276 - accuracy: 0.5215 - val_loss: 1.0913 - val_accuracy: 0.5289 - lr: 4.0000e-04
# Epoch 23/50
# 11/11 [==============================] - 171s 16s/step - loss: 1.0919 - accuracy: 0.5259 - val_loss: 1.0620 - val_accuracy: 0.5200 - lr: 4.0000e-04
# Epoch 24/50
# 11/11 [==============================] - 169s 15s/step - loss: 1.2087 - accuracy: 0.4770 - val_loss: 1.0480 - val_accuracy: 0.5689 - lr: 4.0000e-04
# Epoch 25/50
# 11/11 [==============================] - 170s 16s/step - loss: 1.1316 - accuracy: 0.5067 - val_loss: 1.0284 - val_accuracy: 0.6044 - lr: 4.0000e-04
# Epoch 26/50
# 11/11 [==============================] - 171s 16s/step - loss: 1.0966 - accuracy: 0.5348 - val_loss: 1.0032 - val_accuracy: 0.5911 - lr: 1.6000e-04
# Epoch 27/50
# 11/11 [==============================] - 169s 15s/step - loss: 1.0376 - accuracy: 0.5526 - val_loss: 0.9883 - val_accuracy: 0.6000 - lr: 1.6000e-04
# Epoch 28/50
# 11/11 [==============================] - 169s 15s/step - loss: 1.0266 - accuracy: 0.5704 - val_loss: 1.0007 - val_accuracy: 0.5556 - lr: 1.6000e-04
# Epoch 29/50
# 11/11 [==============================] - 169s 15s/step - loss: 1.0129 - accuracy: 0.5778 - val_loss: 0.9862 - val_accuracy: 0.5867 - lr: 1.6000e-04
# Epoch 30/50
# 11/11 [==============================] - 169s 15s/step - loss: 1.0180 - accuracy: 0.5719 - val_loss: 0.9847 - val_accuracy: 0.5911 - lr: 1.6000e-04
# Epoch 31/50
# 11/11 [==============================] - 169s 15s/step - loss: 0.9947 - accuracy: 0.5985 - val_loss: 0.9551 - val_accuracy: 0.6133 - lr: 1.6000e-04
# Epoch 32/50
# 11/11 [==============================] - 170s 15s/step - loss: 1.0062 - accuracy: 0.5733 - val_loss: 0.9403 - val_accuracy: 0.5956 - lr: 1.6000e-04
# Epoch 33/50
# 11/11 [==============================] - 163s 15s/step - loss: 0.9772 - accuracy: 0.6000 - val_loss: 0.9514 - val_accuracy: 0.6178 - lr: 1.6000e-04
# Epoch 34/50
# 11/11 [==============================] - 157s 14s/step - loss: 0.9664 - accuracy: 0.6311 - val_loss: 0.9432 - val_accuracy: 0.6222 - lr: 1.6000e-04
# Epoch 35/50
# 11/11 [==============================] - 159s 14s/step - loss: 0.9774 - accuracy: 0.5822 - val_loss: 0.9402 - val_accuracy: 0.6044 - lr: 1.6000e-04
# Epoch 36/50
# 11/11 [==============================] - 158s 14s/step - loss: 0.9465 - accuracy: 0.6222 - val_loss: 0.9326 - val_accuracy: 0.6089 - lr: 1.6000e-04
# Epoch 37/50
# 11/11 [==============================] - 205s 19s/step - loss: 0.9510 - accuracy: 0.5630 - val_loss: 0.9333 - val_accuracy: 0.6000 - lr: 1.6000e-04
# Epoch 38/50
# 11/11 [==============================] - 291s 26s/step - loss: 0.9470 - accuracy: 0.5793 - val_loss: 0.9499 - val_accuracy: 0.5867 - lr: 1.6000e-04
# Epoch 39/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.9270 - accuracy: 0.6311 - val_loss: 0.9336 - val_accuracy: 0.6178 - lr: 6.4000e-05
# Epoch 40/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.9268 - accuracy: 0.6059 - val_loss: 0.9137 - val_accuracy: 0.6044 - lr: 6.4000e-05
# Epoch 41/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.9220 - accuracy: 0.6119 - val_loss: 0.9077 - val_accuracy: 0.6133 - lr: 6.4000e-05
# Epoch 42/50
# 11/11 [==============================] - 169s 15s/step - loss: 0.9074 - accuracy: 0.6178 - val_loss: 0.9087 - val_accuracy: 0.6178 - lr: 6.4000e-05
# Epoch 43/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.9324 - accuracy: 0.5956 - val_loss: 0.9145 - val_accuracy: 0.6089 - lr: 6.4000e-05
# Epoch 44/50
# 11/11 [==============================] - 170s 16s/step - loss: 0.8938 - accuracy: 0.6148 - val_loss: 0.9143 - val_accuracy: 0.6178 - lr: 6.4000e-05
# Epoch 45/50
# 11/11 [==============================] - 172s 16s/step - loss: 0.8870 - accuracy: 0.6356 - val_loss: 0.9168 - val_accuracy: 0.6044 - lr: 6.4000e-05
# Epoch 46/50
# 11/11 [==============================] - 170s 15s/step - loss: 0.9139 - accuracy: 0.6222 - val_loss: 0.8989 - val_accuracy: 0.6267 - lr: 6.4000e-05
# Epoch 47/50
# 11/11 [==============================] - 170s 15s/step - loss: 0.8918 - accuracy: 0.6148 - val_loss: 0.8917 - val_accuracy: 0.6400 - lr: 6.4000e-05
# Epoch 48/50
# 11/11 [==============================] - 170s 15s/step - loss: 0.9192 - accuracy: 0.6059 - val_loss: 0.8954 - val_accuracy: 0.6311 - lr: 2.5600e-05
# Epoch 49/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.8963 - accuracy: 0.6237 - val_loss: 0.8972 - val_accuracy: 0.6222 - lr: 2.5600e-05
# Epoch 50/50
# 11/11 [==============================] - 171s 16s/step - loss: 0.8849 - accuracy: 0.6207 - val_loss: 0.8985 - val_accuracy: 0.6267 - lr: 1.0240e-05

# %%
import seaborn as sns

# %%
#from cProfile import label


print("final overall accuracy for test : ", model.evaluate(x_test, y_test)[1]*100, "%")

epochs = [i for i in range(50)]
fig, ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs, train_loss, label ='Loss Train')
ax[0].plot(epochs, test_loss, label ='Loss Test')
ax[0].set_title('Loss || Train and Test')
ax[0].legend()
ax[0].set_xlabel("Iterations")

ax[1].plot(epochs, train_acc, label ='Acc Train')
ax[1].plot(epochs, test_acc, label ='Acc Train')
ax[1].set_title('Accuracy comparison Train and Test')
ax[1].legend()
ax[1].set_xlabel("Iterations")
plt.show
# Out:
# 8/8 [==============================] - 15s 2s/step - loss: 0.8985 - accuracy: 0.6267
# final overall accuracy for test :  62.66666650772095 %
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()
df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          Lateral       Lateral
# 1        Spherical     Spherical
# 2           Palmar        Palmar
# 3        Spherical     Spherical
# 4      Cylindrical       Lateral
# 5          Lateral       Lateral
# 6             Hook          Hook
# 7           Palmar        Palmar
# 8           Palmar        Palmar
# 9              Tip           Tip
